# %% [markdown]
# Deep Learning
# =============
#
# Assignment 2
# ------------
#
# Previously in `1_notmnist.ipynb`, we created a pickle with formatted datasets for training, development and testing on the [notMNIST dataset](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html).
#
# The goal of this assignment is to progressively train deeper and more accurate models using TensorFlow.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (400000, 28, 28) (400000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (400000, 784) (400000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %% [markdown]
# We're first going to train a multinomial logistic regression using simple gradient descent.
#
# TensorFlow works like this:
# * First you describe the computation that you want to see performed: what the inputs, the variables, and the operations look like. These get created as nodes over a computation graph. This description is all contained within the block below:
#
#       with graph.as_default():
#           ...
#
# * Then you can run the operations on this graph as many times as you want by calling `session.run()`, providing it outputs to fetch from the graph that get returned. This runtime operation is all contained in the block below:
#
#       with tf.Session(graph=graph) as session:
#           ...
#
# Let's load all the data into TensorFlow and build the computation graph corresponding to our training:

# %%
# With gradient descent training, even this much data is prohibitive.
# Subset the training data for faster turnaround.
train_subset = 10000

graph = tf.Graph()
with graph.as_default():

  # Input data.
  # Load the training, validation and test data into constants that are
  # attached to the graph.
  tf_train_dataset = tf.constant(train_dataset[:train_subset, :])
  tf_train_labels = tf.constant(train_labels[:train_subset])
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  # These are the parameters that we are going to be training. The weight
  # matrix will be initialized using random values following a (truncated)
  # normal distribution. The biases get initialized to zero.
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  # We multiply the inputs with the weight matrix, and add biases. We compute
  # the softmax and cross-entropy (it's one operation in TensorFlow, because
  # it's very common, and it can be optimized). We take the average of this
  # cross-entropy across all training examples: that's our loss.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
  
  # Optimizer.
  # We are going to find the minimum of this loss using gradient descent.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  # These are not part of training, but merely here so that we can report
  # accuracy figures as we train.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %% [markdown]
# Let's run this computation and iterate:

# %%
num_steps = 801

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

with tf.Session(graph=graph) as session:
  # This is a one-time operation which ensures the parameters get initialized as
  # we described in the graph: random weights for the matrix, zeros for the
  # biases. 
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    # Run the computations. We tell .run() that we want to run the optimizer,
    # and get the loss value and the training predictions returned as numpy
    # arrays.
    _, l, predictions = session.run([optimizer, loss, train_prediction])
    if (step % 100 == 0):
      print('Loss at step %d: %f' % (step, l))
      print('Training accuracy: %.1f%%' % accuracy(
        predictions, train_labels[:train_subset, :]))
      # Calling .eval() on valid_prediction is basically like calling run(), but
      # just to get that one numpy array. Note that it recomputes all its graph
      # dependencies.
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Loss at step 0: 18.982641
# Training accuracy: 10.8%
# Validation accuracy: 12.1%
# Loss at step 100: 2.304457
# Training accuracy: 72.4%
# Validation accuracy: 70.5%
# Loss at step 200: 1.833459
# Training accuracy: 75.5%
# Validation accuracy: 73.2%
# Loss at step 300: 1.588317
# Training accuracy: 77.1%
# Validation accuracy: 74.1%
# Loss at step 400: 1.427656
# Training accuracy: 77.9%
# Validation accuracy: 74.6%
# Loss at step 500: 1.310401
# Training accuracy: 78.8%
# Validation accuracy: 75.2%
# Loss at step 600: 1.218628
# Training accuracy: 79.2%
# Validation accuracy: 75.3%
# Loss at step 700: 1.143644
# Training accuracy: 79.6%
# Validation accuracy: 75.4%
# Loss at step 800: 1.080624
# Training accuracy: 80.1%
# Validation accuracy: 75.5%
# Test accuracy: 82.8%

# %% [markdown]
# Let's now switch to stochastic gradient descent training instead, which is much faster.
#
# The graph will be similar, except that instead of holding all the training data into a constant node, we create a `Placeholder` node which will be fed actual data at every call of `session.run()`.

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %% [markdown]
# Let's run it:

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 19.295206
# Minibatch accuracy: 10.9%
# Validation accuracy: 10.4%
# Minibatch loss at step 500: 1.815021
# Minibatch accuracy: 78.9%
# Validation accuracy: 75.1%
# Minibatch loss at step 1000: 1.334964
# Minibatch accuracy: 71.9%
# Validation accuracy: 76.7%
# Minibatch loss at step 1500: 1.338691
# Minibatch accuracy: 73.4%
# Validation accuracy: 76.8%
# Minibatch loss at step 2000: 1.133822
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.0%
# Minibatch loss at step 2500: 0.918386
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.3%
# Minibatch loss at step 3000: 0.811718
# Minibatch accuracy: 80.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 3500: 0.970820
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.6%
# Minibatch loss at step 4000: 0.938151
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.4%
# Minibatch loss at step 4500: 0.536649
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 5000: 1.043298
# Minibatch accuracy: 74.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 5500: 0.688566
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.1%
# Minibatch loss at step 6000: 0.916393
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 6500: 0.719174
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 7000: 0.793893
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.8%
# Minibatch loss at step 7500: 0.583337
# Minibatch accuracy: 85.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 8000: 0.811213
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 8500: 0.862733
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.6%
# Minibatch loss at step 9000: 0.950524
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.7%
# Minibatch loss at step 9500: 0.618922
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 10000: 0.982622
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.1%
# Test accuracy: 87.5%

# %% [markdown]
# ---
# Problem
# -------
#
# Turn the logistic regression example with SGD into a 1-hidden layer neural network with rectified linear units [nn.relu()](https://www.tensorflow.org/versions/r0.7/api_docs/python/nn.html#relu) and 1024 hidden nodes. This model should improve your validation / test accuracy.
#
# ---

# %% [markdown]
# ### Part 1 - define the network

# %%
batch_size = 128

num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables.
    weights1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
    biases1 = tf.Variable(tf.zeros([num_hidden_nodes]))
    
    weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes, num_labels]))
    biases2 = tf.Variable(tf.zeros([num_labels]))
  
    # Training computation.

    layer_one = tf.matmul(tf_train_dataset, weights1) + biases1
    rel_out = tf.nn.relu(layer_one)  
    logits = tf.matmul(rel_out, weights2) + biases2
    # Loss Function
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
  
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    ## TODO: this bit.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(
                tf.matmul(tf_valid_dataset, weights1) + biases1), 
                  weights2) + biases2)
    test_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(
                tf.matmul(tf_test_dataset, weights1) + biases1), 
                  weights2) + biases2)

# %% [markdown]
# ### Part 2 - run the training steps

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 376.318481
# Minibatch accuracy: 5.5%
# Validation accuracy: 39.1%
# Minibatch loss at step 500: 15.464904
# Minibatch accuracy: 80.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 1000: 18.215145
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.7%
# Minibatch loss at step 1500: 4.613600
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 2000: 7.431980
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 2500: 6.388561
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 3000: 1.445948
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 3500: 3.220186
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.4%
# Minibatch loss at step 4000: 4.201658
# Minibatch accuracy: 78.9%
# Validation accuracy: 82.2%
# Minibatch loss at step 4500: 1.166047
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 5000: 2.313662
# Minibatch accuracy: 77.3%
# Validation accuracy: 82.5%
# Minibatch loss at step 5500: 1.059337
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 6000: 0.903577
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.5%
# Minibatch loss at step 6500: 0.880485
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.0%
# Minibatch loss at step 7000: 1.317821
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.6%
# Minibatch loss at step 7500: 0.975504
# Minibatch accuracy: 89.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 8000: 1.155036
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 8500: 2.006941
# Minibatch accuracy: 75.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 9000: 1.176224
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.3%
# Minibatch loss at step 9500: 0.873816
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.2%
# Minibatch loss at step 10000: 1.239802
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 10500: 0.703092
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 11000: 1.124628
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 11500: 0.706153
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.1%
# Minibatch loss at step 12000: 0.738299
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 12500: 0.861799
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.0%
# Minibatch loss at step 13000: 0.965272
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 13500: 1.864023
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.5%
# Minibatch loss at step 14000: 1.271837
# Minibatch accuracy: 83.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 14500: 0.860421
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 15000: 2.548454
# Minibatch accuracy: 78.9%
# Validation accuracy: 85.6%
# Minibatch loss at step 15500: 0.665547
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 16000: 0.960729
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.5%
# Minibatch loss at step 16500: 0.466902
# Minibatch accuracy: 88.3%
# Validation accuracy: 85.8%
# Minibatch loss at step 17000: 0.835715
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 17500: 0.577340
# Minibatch accuracy: 91.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 18000: 0.574840
# Minibatch accuracy: 91.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 18500: 0.451168
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 19000: 0.588798
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.0%
# Minibatch loss at step 19500: 0.853934
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 20000: 0.547094
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.4%
# Minibatch loss at step 20500: 0.352560
# Minibatch accuracy: 89.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 21000: 1.036644
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 21500: 0.513451
# Minibatch accuracy: 91.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 22000: 0.943882
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 22500: 0.521618
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.0%
# Minibatch loss at step 23000: 0.760743
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 23500: 0.694647
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 24000: 0.533758
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# Minibatch loss at step 24500: 0.926028
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 25000: 0.721219
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Minibatch loss at step 25500: 0.581631
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 26000: 1.000403
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 26500: 0.345357
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.7%
# Minibatch loss at step 27000: 0.399081
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 27500: 0.914607
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.4%
# Minibatch loss at step 28000: 0.484869
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.0%
# Minibatch loss at step 28500: 0.525529
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.0%
# Minibatch loss at step 29000: 0.968701
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 29500: 0.489751
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.9%
# Minibatch loss at step 30000: 0.181228
# Minibatch accuracy: 95.3%
# Validation accuracy: 86.6%
# Minibatch loss at step 30500: 0.333766
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 31000: 0.484212
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 31500: 0.238014
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 32000: 0.501146
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 68500: 0.135110
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 69000: 0.309230
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 69500: 0.210739
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 70000: 0.274174
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 70500: 0.271833
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 71000: 0.298148
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 71500: 0.288794
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 72000: 0.574252
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 72500: 0.123556
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 73000: 0.250194
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 73500: 0.204788
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 74000: 0.189107
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 74500: 0.196748
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 75000: 0.250477
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 75500: 0.084254
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 76000: 0.127086
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 76500: 0.151566
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 77000: 0.354280
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 77500: 0.141722
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 78000: 0.164665
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 78500: 0.202165
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 79000: 0.103886
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 79500: 0.174728
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 80000: 0.161724
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.7%
# Minibatch loss at step 80500: 0.292605
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.7%
# Minibatch loss at step 81000: 0.190911
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 81500: 0.166793
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 82000: 0.092330
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 82500: 0.103996
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.7%
# Minibatch loss at step 83000: 0.205643
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 83500: 0.247615
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 84000: 0.160446
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 84500: 0.083453
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.0%
# Minibatch loss at step 85000: 0.189149
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.5%
# Minibatch loss at step 85500: 0.211368
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 86000: 0.043070
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 86500: 0.066407
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 87000: 0.091789
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 87500: 0.121578
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 88000: 0.131609
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 88500: 0.285842
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.7%
# Minibatch loss at step 89000: 0.125914
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 89500: 0.078627
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 90000: 0.100982
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 90500: 0.117551
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# Minibatch loss at step 91000: 0.176638
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.9%
# Minibatch loss at step 91500: 0.070136
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 92000: 0.155265
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 92500: 0.335811
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 93000: 0.120827
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.7%
# Minibatch loss at step 93500: 0.076991
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.2%
# Minibatch loss at step 94000: 0.116063
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 94500: 0.050768
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 95000: 0.038148
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 95500: 0.105189
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 96000: 0.109857
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 96500: 0.103792
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 97000: 0.083770
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.9%
# Minibatch loss at step 97500: 0.091541
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 98000: 0.077642
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.2%
# Minibatch loss at step 98500: 0.077424
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.0%
# Minibatch loss at step 99000: 0.299366
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 99500: 0.072526
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 100000: 0.106216
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.2%
# Test accuracy: 93.8%

# %% [markdown]
# ### Results:
#
# The test accuracy using the 2-layer network was improved to 89.5% over 86.2% for the simple logistic regression.
#
# - Update: training with 100000 steps gets accuracy of 93.8%
